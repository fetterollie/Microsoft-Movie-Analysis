# %% [markdown]
# ![example](images/director_shot.jpeg)

# %% [markdown]
# # Project Title
#
# **Authors:** Jonathan, Matt, Nate, Roshni
# ***

# %% [markdown]
# ## Overview
#
# A one-paragraph overview of the project, including the business problem, data, methods, results and recommendations.
#
# Microsoft would like open a new movie studio to create original video content. Microsoft wants to know what types of films are currently doing best at the box office. We have generated three actionable insights that will help the head of Microsoft's new movie studio decide on which type of films to create.
#
# * **Which methods did we use?**
#
# * **What are the recommendations?**

# %% [markdown]
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# Which type of films should Microsoft's new movie studio create?
#
# ***
# Questions to consider:
# * What are the business's pain points related to this project?
# * How did you pick the data analysis question(s) that you did?
# * Why are these questions important from a business perspective?
# ***

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
# ***
# Questions to consider:
# * Where did the data come from, and how do they relate to the data analysis questions?
# * What do the data represent? Who is in the sample and what variables are included?
# * What is the target variable?
# * What are the properties of the variables you intend to use?
# ***

# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created?
# * How did you address missing values or outliers?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %% [markdown]
# ### Data Prep The Movies Database

# %% [markdown]
# #### Importing the data as a dataframe
# - Indexing the first column as non-relavent
# - parsing dates to convert to datetime/timestamp

# %%
df_tmdb = pd.read_csv('./zippedData/tmdb.movies.csv.gz', index_col = 0, parse_dates=['release_date'])

# %% [markdown]
# #### Getting a general idea of what the dataset looks like

# %%
df_tmdb
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 9 columns]

# %%
df_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          26517 non-null  object
#  1   id                 26517 non-null  int64
#  2   original_language  26517 non-null  object
#  3   original_title     26517 non-null  object
#  4   popularity         26517 non-null  float64
#  5   release_date       26517 non-null  datetime64[ns]
#  6   title              26517 non-null  object
#  7   vote_average       26517 non-null  float64
#  8   vote_count         26517 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 2.0+ MB

# %% [markdown]
# **Key Takeaways:**
# - 26517 rows with 9 columns of information
# - No null values
# - Need to find a movie genre key to figure out what the genres mean
# - Limit the data to the most recent 10 years to stay relavent
#     - Can maybe also plot vote_avg vs time to see trends that way?

# %% [markdown]
# ### Data Cleaning: The Movies Database
# #### Removing Unnecessary Columns & Filtering Data
# **Columns to drop**
# - `popularity`
#    - popularity is based on current popularity, not how well the movie performed when released or how it was reviewed
#         - https://developers.themoviedb.org/3/getting-started/popularity
#
# - `id`
#     - just a unique identifier, not relevant
#
# - `original_title`
#     - there are two columns for title, we will keep the final title column

# %%
df_cleaning = df_tmdb.drop(['popularity', 'id', 'original_title'], axis=1)

# %% [markdown]
# **Columns to filter**
# - `original_language`
#     - Microsoft would make the language in english as the company is based out of the USA
#
# - `vote_Count`
#     - Microsoft is only interested in a successful movie
#     - It can be reasonably assumed that movies with fewer votes are less successful
#     - We are dropping any count values below the mean
#
# - `release_date`
#     - Microsoft is interested in current data trends
#         - We will limit the data to the last 10 years of available data (2010-2019)

# %% [markdown]
# Making sure that it's only english movies and then dropping the original_language column as it is no longer needed.

# %%
df_filtered = df_cleaning[df_cleaning['original_language'] == 'en']
df_filtered = df_filtered.drop('original_language', axis=1)

# %% [markdown]
# **Drop Certain Movies**
#
# Dropping movies with a vote count below 200 votes.
# (I chose this value as it is roughly the avg of the number of votes in the dataset)

# %%
df_filtered['vote_count'].describe()
# Out:
# count    23291.000000
# mean       209.307887
# std       1016.214512
# min          1.000000
# 25%          1.000000
# 50%          4.000000
# 75%         24.000000
# max      22186.000000
# Name: vote_count, dtype: float64

# %%
df_filtered = df_filtered[df_filtered['vote_count'] > 200]

# %% [markdown]
# Limiting the number of movies to those released in 2010 and after.

# %%
df_filtered = df_filtered[df_filtered['release_date'] > pd.Timestamp(2010, 1, 1)]
df_filtered
# Out:
#                  genre_ids release_date  \
# 0          [12, 14, 10751]   2010-11-19
# 1      [14, 12, 16, 10751]   2010-03-26
# 2            [12, 28, 878]   2010-05-07
# 4            [28, 878, 12]   2010-07-16
# 5          [12, 14, 10751]   2010-02-11
# ...                    ...          ...
# 24369         [18, 36, 35]   2017-11-22
# 24383                 [27]   2018-10-05
# 24409           [9648, 53]   2017-10-27
# 24422             [35, 18]   2018-02-16
# 24472                 [35]   2018-07-20
#
#                                                    title  vote_average  \
# 0           Harry Potter and the Deathly Hallows: Part 1           7.7
# 1                               How to Train Your Dragon           7.7
# 2                                             Iron Man 2           6.8
# 4                                              Inception           8.3
# 5      Percy Jackson & the Olympians: The Lightning T...           6.1
# ...                                                  ...           ...
# 24369                     The Man Who Invented Christmas           6.6
# 24383                                         Malevolent           5.0
# 24409                                   All I See Is You           4.9
# 24422                                          The Party           6.4
# 24472                                 Father of the Year           5.3
#
#        vote_count
# 0           10788
# 1            7610
# 2           12368
# 4           22186
# 5            4229
# ...           ...
# 24369         323
# 24383         236
# 24409         311
# 24422         229
# 24472         235
#
# [2318 rows x 5 columns]

# %% [markdown]
# We are left with the table `df_filtered` that has 2318 rows and 5 columns of relevant information

# %% [markdown]
# ### Understanding the Data

# %% [markdown]
# **Making sense of the genre_ids**
#
# We can see that the genre ID's are in order of best fit rather than numerical or alphabetical order
# - For index 0: `genre_ids` = [12, 14, 10751]
# - For index 1: `genre_ids` = [14, 12, 16, 10751]
#
# We will take the primary and secondary Genre_ids from the list to get a better idea of which Genre's relate to the count

# %% [markdown]
# **Determining the data type for genre_ids**
#
# Checking the type of data for genre_ids below. Goal is to create new columns with primary and secondary genres.

# %%
print(df_filtered['genre_ids'][0])
print(type(df_filtered['genre_ids'][0]))
# Out:
# [12, 14, 10751]
# <class 'str'>

# %% [markdown]
# The data in genre_ids looks like a list, but is really a string including brackets. Let's clean this up.

# %% [markdown]
# **Created a for-loop that runs through each row of the column 'genre_ids'**
#
# The for-loop:
#  - First converts the string to a list of int.
#  - Then it takes each int and assigns it to a new list corresponding to it's position in the original `genre_ids` list.
#  - If there is no value for that iteration, it populates the list with `None`.
#  - I include nonetype so that they stay on point with the correct index.

# %%
char_remove = ["'", " ", "[", "]"]

first_genre = []
second_genre = []

for x in df_filtered['genre_ids']:
    row = x
    for char in char_remove:
        row = row.replace(char, '')
    row = row.split(',')
    first_genre.append(row[0])
        
    if len(row) == 1:
        second_genre.append(None)
    if len(row) >= 2:
        second_genre.append(row[1])

# %% [markdown]
# **Now that we have lists of primary and secondary genre's we can turn them into columns.**

# %%
df_filtered['primary_genre'] = first_genre
df_filtered['secondary_genre'] = second_genre
df_filtered
# Out:
#                  genre_ids release_date  \
# 0          [12, 14, 10751]   2010-11-19
# 1      [14, 12, 16, 10751]   2010-03-26
# 2            [12, 28, 878]   2010-05-07
# 4            [28, 878, 12]   2010-07-16
# 5          [12, 14, 10751]   2010-02-11
# ...                    ...          ...
# 24369         [18, 36, 35]   2017-11-22
# 24383                 [27]   2018-10-05
# 24409           [9648, 53]   2017-10-27
# 24422             [35, 18]   2018-02-16
# 24472                 [35]   2018-07-20
#
#                                                    title  vote_average  \
# 0           Harry Potter and the Deathly Hallows: Part 1           7.7
# 1                               How to Train Your Dragon           7.7
# 2                                             Iron Man 2           6.8
# 4                                              Inception           8.3
# 5      Percy Jackson & the Olympians: The Lightning T...           6.1
# ...                                                  ...           ...
# 24369                     The Man Who Invented Christmas           6.6
# 24383                                         Malevolent           5.0
# 24409                                   All I See Is You           4.9
# 24422                                          The Party           6.4
# 24472                                 Father of the Year           5.3
#
#        vote_count primary_genre secondary_genre
# 0           10788            12              14
# 1            7610            14              12
# 2           12368            12              28
# 4           22186            28             878
# 5            4229            12              14
# ...           ...           ...             ...
# 24369         323            18              36
# 24383         236            27            None
# 24409         311          9648              53
# 24422         229            35              18
# 24472         235            35            None
#
# [2318 rows x 7 columns]

# %% [markdown]
# **Converting the genre_ids codes to something more understandable**
#
# I found the below movie genre key on The MovieDB website. The key is important so that we can understand what the genre_id code actually means.
#
# (found at: https://www.themoviedb.org/talk/5daf6eb0ae36680011d7e6ee)

# %%
backwards_key = {
'Action' : '28',
'Adventure' : '12',
'Animation' : '16',
'Comedy' : '35',
'Crime' : '80',
'Documentary' : '99',
'Drama' : '18',
'Family' : '10751',
'Fantasy' : '14',
'History' : '36',
'Horror' : '27',
'Music' : '10402',
'Mystery' : '9648',
'Romance' : '10749',
'Science Fiction' : '878',
'TV Movie' : '10770',
'Thriller' : '53',
'War' : '10752',
'Western' : '37'
}

genre_key = {v: k for k, v in backwards_key.items()}
# print(genre_key)

# %% [markdown]
# **Now to put the key to work and change the columns from numbers to english**

# %%
df_filtered["primary_genre"].replace(genre_key, inplace=True)
df_filtered["secondary_genre"].replace(genre_key, inplace=True)
df_filtered
# Out:
#                  genre_ids release_date  \
# 0          [12, 14, 10751]   2010-11-19
# 1      [14, 12, 16, 10751]   2010-03-26
# 2            [12, 28, 878]   2010-05-07
# 4            [28, 878, 12]   2010-07-16
# 5          [12, 14, 10751]   2010-02-11
# ...                    ...          ...
# 24369         [18, 36, 35]   2017-11-22
# 24383                 [27]   2018-10-05
# 24409           [9648, 53]   2017-10-27
# 24422             [35, 18]   2018-02-16
# 24472                 [35]   2018-07-20
#
#                                                    title  vote_average  \
# 0           Harry Potter and the Deathly Hallows: Part 1           7.7
# 1                               How to Train Your Dragon           7.7
# 2                                             Iron Man 2           6.8
# 4                                              Inception           8.3
# 5      Percy Jackson & the Olympians: The Lightning T...           6.1
# ...                                                  ...           ...
# 24369                     The Man Who Invented Christmas           6.6
# 24383                                         Malevolent           5.0
# 24409                                   All I See Is You           4.9
# 24422                                          The Party           6.4
# 24472                                 Father of the Year           5.3
#
#        vote_count primary_genre  secondary_genre
# 0           10788     Adventure          Fantasy
# 1            7610       Fantasy        Adventure
# 2           12368     Adventure           Action
# 4           22186        Action  Science Fiction
# 5            4229     Adventure          Fantasy
# ...           ...           ...              ...
# 24369         323         Drama          History
# 24383         236        Horror             None
# 24409         311       Mystery         Thriller
# 24422         229        Comedy            Drama
# 24472         235        Comedy             None
#
# [2318 rows x 7 columns]

# %% [markdown]
# **For our later data analysis, lets combine the two genres into a list of lists that we will add as a third column**
#
# We are going to sort these so that our genre combos come out in the same order, regardless of primary/secondary for easy charting.

# %% [markdown]
# 1) Merge primary and secondary into a list of lists

# %%
merged_genre = [list(x) for x in zip(list(df_filtered['primary_genre']), list(df_filtered['secondary_genre']))]

# %% [markdown]
# 2) Remove any None type from the list of lists for the secondary genres

# %%
for genre in merged_genre:
    if genre[1] == None:
        genre.pop()

# %% [markdown]
# 3) Sort the list based on the values for each list (each row) within the total list

# %%
for genre in merged_genre:
    genre.sort()

# %% [markdown]
# **Now that we have a list of the combined genres, we can turn it into a column.**

# %%
df_filtered['combined_genres'] = merged_genre
df_filtered
# Out:
#                  genre_ids release_date  \
# 0          [12, 14, 10751]   2010-11-19
# 1      [14, 12, 16, 10751]   2010-03-26
# 2            [12, 28, 878]   2010-05-07
# 4            [28, 878, 12]   2010-07-16
# 5          [12, 14, 10751]   2010-02-11
# ...                    ...          ...
# 24369         [18, 36, 35]   2017-11-22
# 24383                 [27]   2018-10-05
# 24409           [9648, 53]   2017-10-27
# 24422             [35, 18]   2018-02-16
# 24472                 [35]   2018-07-20
#
#                                                    title  vote_average  \
# 0           Harry Potter and the Deathly Hallows: Part 1           7.7
# 1                               How to Train Your Dragon           7.7
# 2                                             Iron Man 2           6.8
# 4                                              Inception           8.3
# 5      Percy Jackson & the Olympians: The Lightning T...           6.1
# ...                                                  ...           ...
# 24369                     The Man Who Invented Christmas           6.6
# 24383                                         Malevolent           5.0
# 24409                                   All I See Is You           4.9
# 24422                                          The Party           6.4
# 24472                                 Father of the Year           5.3
#
#        vote_count primary_genre  secondary_genre            combined_genres
# 0           10788     Adventure          Fantasy       [Adventure, Fantasy]
# 1            7610       Fantasy        Adventure       [Adventure, Fantasy]
# 2           12368     Adventure           Action        [Action, Adventure]
# 4           22186        Action  Science Fiction  [Action, Science Fiction]
# 5            4229     Adventure          Fantasy       [Adventure, Fantasy]
# ...           ...           ...              ...                        ...
# 24369         323         Drama          History           [Drama, History]
# 24383         236        Horror             None                   [Horror]
# 24409         311       Mystery         Thriller        [Mystery, Thriller]
# 24422         229        Comedy            Drama            [Comedy, Drama]
# 24472         235        Comedy             None                   [Comedy]
#
# [2318 rows x 8 columns]

# %% [markdown]
# ### Data Prep The Numbers Database

# %% [markdown]
# **Importing the Data as a Dataframe**

# %%
tn_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz', parse_dates=['release_date'])

# %% [markdown]
# #### Remove unnecessary column (ID)

# %%
tn_df = tn_df.drop('id', axis=1)

# %% [markdown]
# #### Convert Number Variables to Int type

# %%
tn_df['production_budget'].replace(',','', regex=True, inplace=True)
tn_df['production_budget'] = tn_df['production_budget'].map(lambda x: x.replace('$',''))

tn_df['domestic_gross'].replace(',','', regex=True, inplace=True)
tn_df['domestic_gross'] = tn_df['domestic_gross'].map(lambda x: x.replace('$',''))

tn_df['worldwide_gross'].replace(',','', regex=True, inplace=True)
tn_df['worldwide_gross'] = tn_df['worldwide_gross'].map(lambda x: x.replace('$',''))

tn_df['production_budget'] = tn_df['production_budget'].astype(int)
tn_df['domestic_gross'] = tn_df['domestic_gross'].astype(int)
tn_df['worldwide_gross'] = tn_df['worldwide_gross'].astype(int)

tn_df
# Out:
#      release_date                                        movie  \
# 0      2009-12-18                                       Avatar
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      2019-06-07                                 Dark Phoenix
# 3      2015-05-01                      Avengers: Age of Ultron
# 4      2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...           ...                                          ...
# 5777   2018-12-31                                       Red 11
# 5778   1999-04-02                                    Following
# 5779   2005-07-13                Return to the Land of Wonders
# 5780   2015-09-29                         A Plague So Pleasant
# 5781   2005-08-05                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5777               7000               0                0
# 5778               6000           48482           240495
# 5779               5000            1338             1338
# 5780               1400               0                0
# 5781               1100          181041           181041
#
# [5782 rows x 5 columns]

# %% [markdown]
# #### Excluding Worldwide Gross == 0
# - Worldwide Gross of 0 indicates that either the data is missing data or the movie was never released in theaters.

# %%
print("Excluding worldwide gross of $0 would remove " + str(round((1 - 5415/5781)*100, 1)) + " percent of datapoints")

#Less than 10% of data is being removed, which meets the rule of thumb


tn_df = tn_df[tn_df['worldwide_gross'] != 0]

tn_df
# Out:
# Excluding worldwide gross of $0 would remove 6.3 percent of datapoints
#      release_date                                        movie  \
# 0      2009-12-18                                       Avatar
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      2019-06-07                                 Dark Phoenix
# 3      2015-05-01                      Avengers: Age of Ultron
# 4      2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...           ...                                          ...
# 5775   2006-05-26                                       Cavite
# 5776   2004-12-31                              The Mongol King
# 5778   1999-04-02                                    Following
# 5779   2005-07-13                Return to the Land of Wonders
# 5781   2005-08-05                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5775               7000           70071            71644
# 5776               7000             900              900
# 5778               6000           48482           240495
# 5779               5000            1338             1338
# 5781               1100          181041           181041
#
# [5415 rows x 5 columns]

# %% [markdown]
# #### Calculate Net Profit as a new variable in dataset

# %% [markdown]
# Net profit = worldwide gross - production budget

# %%
tn_df = tn_df.assign(net_profit = tn_df['worldwide_gross'] - tn_df['production_budget'])
tn_df
# Out:
#      release_date                                        movie  \
# 0      2009-12-18                                       Avatar
# 1      2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      2019-06-07                                 Dark Phoenix
# 3      2015-05-01                      Avengers: Age of Ultron
# 4      2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...           ...                                          ...
# 5775   2006-05-26                                       Cavite
# 5776   2004-12-31                              The Mongol King
# 5778   1999-04-02                                    Following
# 5779   2005-07-13                Return to the Land of Wonders
# 5781   2005-08-05                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  net_profit
# 0             425000000       760507625       2776345279  2351345279
# 1             410600000       241063875       1045663875   635063875
# 2             350000000        42762350        149762350  -200237650
# 3             330600000       459005868       1403013963  1072413963
# 4             317000000       620181382       1316721747   999721747
# ...                 ...             ...              ...         ...
# 5775               7000           70071            71644       64644
# 5776               7000             900              900       -6100
# 5778               6000           48482           240495      234495
# 5779               5000            1338             1338       -3662
# 5781               1100          181041           181041      179941
#
# [5415 rows x 6 columns]

# %% [markdown]
# ### Data Prep The IMDb
#
# Opening up the database and examining the tables:
#
# In order to run this notebook, you will need to download the necessary data file. A zipped version of the file can be downloaded: here.
#
# Download the zipped file into a folder called 'zippedData' within the same folder that this notebook is located. Once this zip file is in located in the zippedData folder, you can run the following cell to unzip it.

# %%
import zipfile
with zipfile.ZipFile('zippedData/im.db.zip', 'r') as zip_ref:
    zip_ref.extractall('zippedData')

# %% [markdown]
# Run the following cell to confirm that the database file has been downloaded and unzipped to the correct folder:

# %%
from os.path import exists
file_exists = exists('zippedData/im.db')
if file_exists:
    print("You have successfully downloaded and unzipped the database file.  Please proceed.")
else:
    print("The database file was not found.  Please ensure that the database file has been downloaded and unzipped into the 'zippedData' folder located in the folder that this Jupyter notebook resides.")
# Out:
# You have successfully downloaded and unzipped the database file.  Please proceed.

# %% [markdown]
# First, we want to open up the database and examine the database tables.

# %%
import sqlite3

con = sqlite3.connect('zippedData/im.db')
query = """  SELECT * FROM sqlite_master  """
tables = pd.read_sql(query, con)
tables
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %% [markdown]
# **Tables of initial interest:**
# 1. movie_basics
# 2. movie_ratings

# %% [markdown]
# #### Examine Movie Basics table

# %%
query = """  SELECT * FROM movie_basics  """
movie_basics = pd.read_sql(query, con)
movie_basics.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
movie_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# **Notes:**
# - This table has the movie titles, release year, and genres.  The primary key is the movie_id, which is referenced in other tables such as movie basics.
# - There appears to be a movie_id, primary title, and start_year for all rows.

# %% [markdown]
# #### Examine Movie Ratings table

# %%
query = """  SELECT * FROM movie_ratings  """
movie_ratings = pd.read_sql(query, con)
movie_ratings
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
movie_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# **Notes:**
# - Movie ratings are only given for 73K of the 146K of movies.
# - Since the ratings are the most important quantitate information from this file, I would suggest we

# %% [markdown]
# #### Merge Tables
# - merging `movie_ratings` with `movie_basics`

# %%
movies_with_ratings = pd.merge(movie_ratings, movie_basics, left_on='movie_id', right_on='movie_id')
movies_with_ratings
# Out:
#          movie_id  averagerating  numvotes  \
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
#                                            primary_title  \
# 0                                       Laiye Je Yaarian
# 1                                             Borderless
# 2                                              Just Inès
# 3                                 The Legend of Hercules
# 4                                              Até Onde?
# ...                                                  ...
# 73851                                              Caisa
# 73852  Code Geass: Lelouch of the Rebellion - Glorifi...
# 73853                                            Sisters
# 73854                                  The Projectionist
# 73855                                             Sathru
#
#                                          original_title  start_year  \
# 0                                      Laiye Je Yaarian        2019
# 1                                            Borderless        2019
# 2                                             Just Inès        2010
# 3                                The Legend of Hercules        2014
# 4                                             Até Onde?        2011
# ...                                                 ...         ...
# 73851                                             Caisa        2018
# 73852  Code Geass: Lelouch of the Rebellion Episode III        2018
# 73853                                           Sisters        2019
# 73854                                 The Projectionist        2019
# 73855                                            Sathru        2019
#
#        runtime_minutes                    genres
# 0                117.0                   Romance
# 1                 87.0               Documentary
# 2                 90.0                     Drama
# 3                 99.0  Action,Adventure,Fantasy
# 4                 73.0          Mystery,Thriller
# ...                ...                       ...
# 73851             84.0               Documentary
# 73852            120.0   Action,Animation,Sci-Fi
# 73853              NaN              Action,Drama
# 73854             81.0               Documentary
# 73855            129.0                  Thriller
#
# [73856 rows x 8 columns]

# %% [markdown]
# #### Filter Movies
# We want to consider the number of votes in our results, as the fewer number of votes a movie rating has will lead to less certainty in the average rating. As such, we decided to cut the analysis to the top half (all movies over the median number of votes, which is 49).

# %% [markdown]
# Find the median number of votes in the remaining data set

# %%
median_votes = movies_with_ratings['numvotes'].median()
median_votes
# Out:
# 49.0

# %% [markdown]
# Drop movies with number of votes less than the median

# %%
movies_with_ratings_over_median_votes = movies_with_ratings.loc[movies_with_ratings['numvotes']>median_votes]
movies_with_ratings_over_median_votes
# Out:
#          movie_id  averagerating  numvotes           primary_title  \
# 1      tt10384606            8.9       559              Borderless
# 3       tt1043726            4.2     50352  The Legend of Hercules
# 5       tt1069246            6.2       326              Habana Eva
# 6       tt1094666            7.0      1613              The Hammer
# 7       tt1130982            6.4       571         The Night Clerk
# ...           ...            ...       ...                     ...
# 73831   tt9558612            3.7      4057        PM Narendra Modi
# 73832   tt9575726            7.7       161        Ir visi ju vyrai
# 73833   tt9576110            6.8        65        J'veux du soleil
# 73844   tt9668598            5.5       317                Musabbar
# 73855   tt9894098            6.3       128                  Sathru
#
#                original_title  start_year  runtime_minutes  \
# 1                  Borderless        2019             87.0
# 3      The Legend of Hercules        2014             99.0
# 5                  Habana Eva        2010            106.0
# 6                      Hamill        2010            108.0
# 7                Avant l'aube        2011            104.0
# ...                       ...         ...              ...
# 73831        PM Narendra Modi        2019            136.0
# 73832        Ir visi ju vyrai        2019            108.0
# 73833        J'veux du soleil        2019             76.0
# 73844                Musabbar        2019              NaN
# 73855                  Sathru        2019            129.0
#
#                          genres
# 1                   Documentary
# 3      Action,Adventure,Fantasy
# 5                Comedy,Romance
# 6         Biography,Drama,Sport
# 7                Drama,Thriller
# ...                         ...
# 73831           Biography,Drama
# 73832            Comedy,Romance
# 73833               Documentary
# 73844           Horror,Thriller
# 73855                  Thriller
#
# [36824 rows x 8 columns]

# %% [markdown]
# We now have a dataset of ~37K movies that all have a sufficient number of votes for us to be confident in the average ratings. We can now analyze the dataset.

# %% [markdown]
# ### Joining DF

# %% [markdown]
# Prep The Movies Database to join:

# %%
df_tmdb_mod = df_filtered
df_tmdb_mod['movie'] = df_tmdb_mod['title']
df_tmdb_mod = df_tmdb_mod.set_index('movie')
df_tmdb_mod = df_tmdb_mod.drop('genre_ids', axis=1)
df_tmdb_mod.head(1)
# Out:
#                                              release_date  \
# movie
# Harry Potter and the Deathly Hallows: Part 1   2010-11-19
#
#                                                                                      title  \
# movie
# Harry Potter and the Deathly Hallows: Part 1  Harry Potter and the Deathly Hallows: Part 1
#
#                                               vote_average  vote_count  \
# movie
# Harry Potter and the Deathly Hallows: Part 1           7.7       10788
#
#                                              primary_genre secondary_genre  \
# movie
# Harry Potter and the Deathly Hallows: Part 1     Adventure         Fantasy
#
#                                                    combined_genres
# movie
# Harry Potter and the Deathly Hallows: Part 1  [Adventure, Fantasy]

# %% [markdown]
# Prep The Numbers Database to join:

# %%
df_tndb_mod = tn_df.set_index('movie')
df_tndb_mod = df_tndb_mod.drop('release_date', axis=1)
df_tndb_mod.head(1)
# Out:
#         production_budget  domestic_gross  worldwide_gross  net_profit
# movie
# Avatar          425000000       760507625       2776345279  2351345279

# %% [markdown]
# Joining The Movied Database with The Numbers Database

# %%
df_tmdb_tn_innerjoin = df_tmdb_mod.join(df_tndb_mod, on='movie', how='inner', lsuffix='tmdb', rsuffix='tn')
df_tmdb_tn_innerjoin
# Out:
#                                                    release_date  \
# movie
# How to Train Your Dragon                             2010-03-26
# Iron Man 2                                           2010-05-07
# Inception                                            2010-07-16
# Percy Jackson & the Olympians: The Lightning Thief   2010-02-11
# Toy Story 3                                          2010-06-17
# ...                                                         ...
# The 15:17 to Paris                                   2018-02-09
# Book Club                                            2018-05-18
# Uncle Drew                                           2018-06-29
# Gotti                                                2018-06-15
# Proud Mary                                           2018-01-12
#
#                                                                                                 title  \
# movie
# How to Train Your Dragon                                                     How to Train Your Dragon
# Iron Man 2                                                                                 Iron Man 2
# Inception                                                                                   Inception
# Percy Jackson & the Olympians: The Lightning Thief  Percy Jackson & the Olympians: The Lightning T...
# Toy Story 3                                                                               Toy Story 3
# ...                                                                                               ...
# The 15:17 to Paris                                                                 The 15:17 to Paris
# Book Club                                                                                   Book Club
# Uncle Drew                                                                                 Uncle Drew
# Gotti                                                                                           Gotti
# Proud Mary                                                                                 Proud Mary
#
#                                                     vote_average  vote_count  \
# movie
# How to Train Your Dragon                                     7.7        7610
# Iron Man 2                                                   6.8       12368
# Inception                                                    8.3       22186
# Percy Jackson & the Olympians: The Lightning Thief           6.1        4229
# Toy Story 3                                                  7.7        8340
# ...                                                          ...         ...
# The 15:17 to Paris                                           5.3         799
# Book Club                                                    6.0         301
# Uncle Drew                                                   6.5         220
# Gotti                                                        5.2         231
# Proud Mary                                                   5.5         259
#
#                                                    primary_genre  \
# movie
# How to Train Your Dragon                                 Fantasy
# Iron Man 2                                             Adventure
# Inception                                                 Action
# Percy Jackson & the Olympians: The Lightning Thief     Adventure
# Toy Story 3                                            Animation
# ...                                                          ...
# The 15:17 to Paris                                         Drama
# Book Club                                                 Comedy
# Uncle Drew                                                Comedy
# Gotti                                                      Crime
# Proud Mary                                              Thriller
#
#                                                     secondary_genre  \
# movie
# How to Train Your Dragon                                  Adventure
# Iron Man 2                                                   Action
# Inception                                           Science Fiction
# Percy Jackson & the Olympians: The Lightning Thief          Fantasy
# Toy Story 3                                                  Family
# ...                                                             ...
# The 15:17 to Paris                                          History
# Book Club                                                   Romance
# Uncle Drew                                                     None
# Gotti                                                         Drama
# Proud Mary                                                   Action
#
#                                                               combined_genres  \
# movie
# How to Train Your Dragon                                 [Adventure, Fantasy]
# Iron Man 2                                                [Action, Adventure]
# Inception                                           [Action, Science Fiction]
# Percy Jackson & the Olympians: The Lightning Thief       [Adventure, Fantasy]
# Toy Story 3                                               [Animation, Family]
# ...                                                                       ...
# The 15:17 to Paris                                           [Drama, History]
# Book Club                                                   [Comedy, Romance]
# Uncle Drew                                                           [Comedy]
# Gotti                                                          [Crime, Drama]
# Proud Mary                                                 [Action, Thriller]
#
#                                                     production_budget  \
# movie
# How to Train Your Dragon                                    165000000
# Iron Man 2                                                  170000000
# Inception                                                   160000000
# Percy Jackson & the Olympians: The Lightning Thief           95000000
# Toy Story 3                                                 200000000
# ...                                                               ...
# The 15:17 to Paris                                           30000000
# Book Club                                                    10000000
# Uncle Drew                                                   18000000
# Gotti                                                        10000000
# Proud Mary                                                   30000000
#
#                                                     domestic_gross  \
# movie
# How to Train Your Dragon                                 217581232
# Iron Man 2                                               312433331
# Inception                                                292576195
# Percy Jackson & the Olympians: The Lightning Thief        88768303
# Toy Story 3                                              415004880
# ...                                                            ...
# The 15:17 to Paris                                        36276286
# Book Club                                                 68566296
# Uncle Drew                                                42469946
# Gotti                                                      4286367
# Proud Mary                                                20868638
#
#                                                     worldwide_gross  \
# movie
# How to Train Your Dragon                                  494870992
# Iron Man 2                                                621156389
# Inception                                                 835524642
# Percy Jackson & the Olympians: The Lightning Thief        223050874
# Toy Story 3                                              1068879522
# ...                                                             ...
# The 15:17 to Paris                                         56096200
# Book Club                                                  91113683
# Uncle Drew                                                 46527161
# Gotti                                                       6089100
# Proud Mary                                                 21709539
#
#                                                     net_profit
# movie
# How to Train Your Dragon                             329870992
# Iron Man 2                                           451156389
# Inception                                            675524642
# Percy Jackson & the Olympians: The Lightning Thief   128050874
# Toy Story 3                                          868879522
# ...                                                        ...
# The 15:17 to Paris                                    26096200
# Book Club                                             81113683
# Uncle Drew                                            28527161
# Gotti                                                 -3910900
# Proud Mary                                            -8290461
#
# [1424 rows x 11 columns]

# %% [markdown]
# Prep IMDB to join:

# %%
df_imdb_mod = movies_with_ratings_over_median_votes
df_imdb_mod['movie'] = df_imdb_mod['primary_title']
df_imdb_mod = df_imdb_mod.set_index('movie')
df_imdb_mod = df_imdb_mod.drop(['movie_id', 'original_title', 'genres'], axis=1)
df_imdb_mod#.head(1)
# Out:
# <ipython-input-41-7904651527f7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imdb_mod['movie'] = df_imdb_mod['primary_title']
#                         averagerating  numvotes           primary_title  \
# movie
# Borderless                        8.9       559              Borderless
# The Legend of Hercules            4.2     50352  The Legend of Hercules
# Habana Eva                        6.2       326              Habana Eva
# The Hammer                        7.0      1613              The Hammer
# The Night Clerk                   6.4       571         The Night Clerk
# ...                               ...       ...                     ...
# PM Narendra Modi                  3.7      4057        PM Narendra Modi
# Ir visi ju vyrai                  7.7       161        Ir visi ju vyrai
# J'veux du soleil                  6.8        65        J'veux du soleil
# Musabbar                          5.5       317                Musabbar
# Sathru                            6.3       128                  Sathru
#
#                         start_year  runtime_minutes
# movie
# Borderless                    2019             87.0
# The Legend of Hercules        2014             99.0
# Habana Eva                    2010            106.0
# The Hammer                    2010            108.0
# The Night Clerk               2011            104.0
# ...                            ...              ...
# PM Narendra Modi              2019            136.0
# Ir visi ju vyrai              2019            108.0
# J'veux du soleil              2019             76.0
# Musabbar                      2019              NaN
# Sathru                        2019            129.0
#
# [36824 rows x 5 columns]

# %%
df_all_inner_join = df_tmdb_tn_innerjoin.join(df_imdb_mod, on='movie', how='inner')
df_all_inner_join
# Out:
#                                                    release_date  \
# movie
# How to Train Your Dragon                             2010-03-26
# Iron Man 2                                           2010-05-07
# Inception                                            2010-07-16
# Percy Jackson & the Olympians: The Lightning Thief   2010-02-11
# Toy Story 3                                          2010-06-17
# ...                                                         ...
# The 15:17 to Paris                                   2018-02-09
# Book Club                                            2018-05-18
# Uncle Drew                                           2018-06-29
# Gotti                                                2018-06-15
# Proud Mary                                           2018-01-12
#
#                                                                                                 title  \
# movie
# How to Train Your Dragon                                                     How to Train Your Dragon
# Iron Man 2                                                                                 Iron Man 2
# Inception                                                                                   Inception
# Percy Jackson & the Olympians: The Lightning Thief  Percy Jackson & the Olympians: The Lightning T...
# Toy Story 3                                                                               Toy Story 3
# ...                                                                                               ...
# The 15:17 to Paris                                                                 The 15:17 to Paris
# Book Club                                                                                   Book Club
# Uncle Drew                                                                                 Uncle Drew
# Gotti                                                                                           Gotti
# Proud Mary                                                                                 Proud Mary
#
#                                                     vote_average  vote_count  \
# movie
# How to Train Your Dragon                                     7.7        7610
# Iron Man 2                                                   6.8       12368
# Inception                                                    8.3       22186
# Percy Jackson & the Olympians: The Lightning Thief           6.1        4229
# Toy Story 3                                                  7.7        8340
# ...                                                          ...         ...
# The 15:17 to Paris                                           5.3         799
# Book Club                                                    6.0         301
# Uncle Drew                                                   6.5         220
# Gotti                                                        5.2         231
# Proud Mary                                                   5.5         259
#
#                                                    primary_genre  \
# movie
# How to Train Your Dragon                                 Fantasy
# Iron Man 2                                             Adventure
# Inception                                                 Action
# Percy Jackson & the Olympians: The Lightning Thief     Adventure
# Toy Story 3                                            Animation
# ...                                                          ...
# The 15:17 to Paris                                         Drama
# Book Club                                                 Comedy
# Uncle Drew                                                Comedy
# Gotti                                                      Crime
# Proud Mary                                              Thriller
#
#                                                     secondary_genre  \
# movie
# How to Train Your Dragon                                  Adventure
# Iron Man 2                                                   Action
# Inception                                           Science Fiction
# Percy Jackson & the Olympians: The Lightning Thief          Fantasy
# Toy Story 3                                                  Family
# ...                                                             ...
# The 15:17 to Paris                                          History
# Book Club                                                   Romance
# Uncle Drew                                                     None
# Gotti                                                         Drama
# Proud Mary                                                   Action
#
#                                                               combined_genres  \
# movie
# How to Train Your Dragon                                 [Adventure, Fantasy]
# Iron Man 2                                                [Action, Adventure]
# Inception                                           [Action, Science Fiction]
# Percy Jackson & the Olympians: The Lightning Thief       [Adventure, Fantasy]
# Toy Story 3                                               [Animation, Family]
# ...                                                                       ...
# The 15:17 to Paris                                           [Drama, History]
# Book Club                                                   [Comedy, Romance]
# Uncle Drew                                                           [Comedy]
# Gotti                                                          [Crime, Drama]
# Proud Mary                                                 [Action, Thriller]
#
#                                                     production_budget  \
# movie
# How to Train Your Dragon                                    165000000
# Iron Man 2                                                  170000000
# Inception                                                   160000000
# Percy Jackson & the Olympians: The Lightning Thief           95000000
# Toy Story 3                                                 200000000
# ...                                                               ...
# The 15:17 to Paris                                           30000000
# Book Club                                                    10000000
# Uncle Drew                                                   18000000
# Gotti                                                        10000000
# Proud Mary                                                   30000000
#
#                                                     domestic_gross  \
# movie
# How to Train Your Dragon                                 217581232
# Iron Man 2                                               312433331
# Inception                                                292576195
# Percy Jackson & the Olympians: The Lightning Thief        88768303
# Toy Story 3                                              415004880
# ...                                                            ...
# The 15:17 to Paris                                        36276286
# Book Club                                                 68566296
# Uncle Drew                                                42469946
# Gotti                                                      4286367
# Proud Mary                                                20868638
#
#                                                     worldwide_gross  \
# movie
# How to Train Your Dragon                                  494870992
# Iron Man 2                                                621156389
# Inception                                                 835524642
# Percy Jackson & the Olympians: The Lightning Thief        223050874
# Toy Story 3                                              1068879522
# ...                                                             ...
# The 15:17 to Paris                                         56096200
# Book Club                                                  91113683
# Uncle Drew                                                 46527161
# Gotti                                                       6089100
# Proud Mary                                                 21709539
#
#                                                     net_profit  averagerating  \
# movie
# How to Train Your Dragon                             329870992            8.1
# Iron Man 2                                           451156389            7.0
# Inception                                            675524642            8.8
# Percy Jackson & the Olympians: The Lightning Thief   128050874            5.9
# Toy Story 3                                          868879522            8.3
# ...                                                        ...            ...
# The 15:17 to Paris                                    26096200            5.2
# Book Club                                             81113683            6.1
# Uncle Drew                                            28527161            5.7
# Gotti                                                 -3910900            4.8
# Proud Mary                                            -8290461            4.9
#
#                                                     numvotes  \
# movie
# How to Train Your Dragon                              611299
# Iron Man 2                                            657690
# Inception                                            1841066
# Percy Jackson & the Olympians: The Lightning Thief    165108
# Toy Story 3                                           682218
# ...                                                      ...
# The 15:17 to Paris                                     21880
# Book Club                                              18728
# Uncle Drew                                              9739
# Gotti                                                  10358
# Proud Mary                                              6805
#
#                                                                                         primary_title  \
# movie
# How to Train Your Dragon                                                     How to Train Your Dragon
# Iron Man 2                                                                                 Iron Man 2
# Inception                                                                                   Inception
# Percy Jackson & the Olympians: The Lightning Thief  Percy Jackson & the Olympians: The Lightning T...
# Toy Story 3                                                                               Toy Story 3
# ...                                                                                               ...
# The 15:17 to Paris                                                                 The 15:17 to Paris
# Book Club                                                                                   Book Club
# Uncle Drew                                                                                 Uncle Drew
# Gotti                                                                                           Gotti
# Proud Mary                                                                                 Proud Mary
#
#                                                     start_year  \
# movie
# How to Train Your Dragon                                  2010
# Iron Man 2                                                2010
# Inception                                                 2010
# Percy Jackson & the Olympians: The Lightning Thief        2010
# Toy Story 3                                               2010
# ...                                                        ...
# The 15:17 to Paris                                        2018
# Book Club                                                 2018
# Uncle Drew                                                2018
# Gotti                                                     2018
# Proud Mary                                                2018
#
#                                                     runtime_minutes
# movie
# How to Train Your Dragon                                       98.0
# Iron Man 2                                                    124.0
# Inception                                                     148.0
# Percy Jackson & the Olympians: The Lightning Thief            118.0
# Toy Story 3                                                   103.0
# ...                                                             ...
# The 15:17 to Paris                                             94.0
# Book Club                                                     104.0
# Uncle Drew                                                    103.0
# Gotti                                                         112.0
# Proud Mary                                                     89.0
#
# [1571 rows x 16 columns]

# %% [markdown]
# ## Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
ylabel = df_tmdb_tn_innerjoin.groupby(['primary_genre']).mean().sort_values(by='worldwide_gross', ascending=False)
xlabel = list(df_tmdb_tn_innerjoin.groupby(['primary_genre']).mean().sort_values(by='worldwide_gross', ascending=False).index)

# Setting the figure and figure size
fig, ax = plt.subplots(figsize=(20, 12))

# creating the graph using our xlabel and ylabel that we defined above
ax.bar(x= xlabel, height = ylabel['worldwide_gross'])
# setting axis labels and title
ax.set_title('Average Worldwide Gross per Genre')
ax.set_xlabel('Movie Genre Categories')
ax.set_ylabel('worldwide_gross')
ax.set_ylim()
# setting bar labels for each average value over their respective column
for loc, label in enumerate(ylabel['worldwide_gross']):
    ax.text(loc, label+.15, str(round(label, ndigits=2)), ha='center');

# %%
ylabel
# Out:
#                  vote_average   vote_count  production_budget  domestic_gross  \
# primary_genre
# Family               6.293750  3436.187500       7.000000e+07    1.473647e+08
# Animation            6.720000  3293.020000       1.016840e+08    1.416414e+08
# Western              7.100000  7505.666667       9.533333e+07    1.232353e+08
# Adventure            6.457576  4047.070707       1.095384e+08    1.206583e+08
# Action               6.258333  3859.677536       8.914239e+07    1.057766e+08
# Science Fiction      6.433333  4875.871795       7.510513e+07    9.911176e+07
# War                  6.590000  3796.900000       6.735000e+07    1.207578e+08
# Fantasy              6.224242  2605.424242       8.382727e+07    7.592740e+07
# Mystery              6.264286  3425.428571       3.228571e+07    5.633247e+07
# Romance              6.646341  2036.634146       2.555610e+07    5.111123e+07
# Music                6.850000   816.000000       3.650000e+07    4.106084e+07
# History              6.987500  2275.875000       2.600000e+07    5.084103e+07
# Horror               5.851546  1791.649485       1.553041e+07    3.779515e+07
# Thriller             6.130769  1775.252747       2.923049e+07    3.757782e+07
# Comedy               6.218672  1394.165975       2.850311e+07    4.573306e+07
# Drama                6.807645  2124.483180       2.622979e+07    3.860358e+07
# Crime                6.574667  2227.520000       3.215653e+07    3.673668e+07
# Documentary          6.450000   353.000000       7.500000e+06    3.866287e+07
#
#                  worldwide_gross    net_profit
# primary_genre
# Family              3.806138e+08  3.106138e+08
# Animation           4.077239e+08  3.060399e+08
# Western             3.580314e+08  2.626981e+08
# Adventure           3.408848e+08  2.313464e+08
# Action              2.883947e+08  1.992523e+08
# Science Fiction     2.625068e+08  1.874017e+08
# War                 2.236720e+08  1.563220e+08
# Fantasy             2.092087e+08  1.253815e+08
# Mystery             1.296721e+08  9.738644e+07
# Romance             1.131036e+08  8.754750e+07
# Music               1.154175e+08  7.891751e+07
# History             1.027637e+08  7.676366e+07
# Horror              7.982325e+07  6.429284e+07
# Thriller            8.871855e+07  5.948806e+07
# Comedy              8.582990e+07  5.732679e+07
# Drama               8.297725e+07  5.674745e+07
# Crime               8.435829e+07  5.220176e+07
# Documentary         5.341669e+07  4.591669e+07

# %%
ylabel = df_tmdb_tn_innerjoin.groupby(['primary_genre']).mean().sort_values(by='net_profit', ascending=False)
xlabel = list(df_tmdb_tn_innerjoin.groupby(['primary_genre']).mean().sort_values(by='net_profit', ascending=False).index)

# Setting the figure and figure size
fig, ax = plt.subplots(figsize=(20, 12))

# creating the graph using our xlabel and ylabel that we defined above
ax.bar(x= xlabel, height = ylabel['net_profit'])
# setting axis labels and title
ax.set_title('Average net_profit per Genre')
ax.set_xlabel('Movie Genre Categories')
ax.set_ylabel('net_profit')
ax.set_ylim()
# setting bar labels for each average value over their respective column
for loc, label in enumerate(ylabel['net_profit']):
    ax.text(loc, label+.15, str(round(label, ndigits=2)), ha='center');

# %%
# Here you run your code to model the data

# %% [markdown]
# ## Evaluation
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# ## Conclusions
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***
